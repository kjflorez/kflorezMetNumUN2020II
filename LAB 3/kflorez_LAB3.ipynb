# %% [markdown]
# <a href="https://colab.research.google.com/github/kjflorez/kflorezMetNumUN2020II/blob/main/LAB%203/kflorez_LAB3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Link Linkedin**
# [texto del enlace](https://www.linkedin.com/in/karen-j-florez-pardo-/)

# %% [markdown]
# ![kflorezcognitiveclassaapplieddatadciencewithpython.jpg](data:image/jpeg;base64,...)
